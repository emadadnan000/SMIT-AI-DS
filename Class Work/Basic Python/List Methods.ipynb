# %% [markdown]
# # List Methods

# %% [markdown]
# ## list.sort()
# This method sorts the list in ascending order. The original list is updated

# %%
colors = ["voilet", "indigo", "blue", "green"]
colors.sort()
print(colors)


num = [4,2,5,3,6,1,2,1,2,8,9,7]
num.sort()
print(num)
# Out:
# ['blue', 'green', 'indigo', 'voilet']
# [1, 1, 2, 2, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
ages = [14 , 34 , 18  , 77 , 21 , 27]
ages.sort()

# %%
print(ages)
# Out:
# [14, 18, 21, 27, 34, 77]

# %% [markdown]
# What if you want to print the list in descending order?
# We must give reverse=True as a parameter in the sort method.

# %%
colors = ["voilet", "indigo", "blue", "green"]
colors.sort(reverse = True)
print(colors)
# Out:
# ['voilet', 'indigo', 'green', 'blue']

# %%
print(colors)
# Out:
# ['voilet', 'indigo', 'green', 'blue']

# %%
ages.sort(reverse = True)
print(ages)
# Out:
# [77, 34, 27, 21, 18, 14]

# %% [markdown]
# The reverse parameter is set to False by default.
#
# Note: Do not mistake the reverse parameter with the reverse method.

# %% [markdown]
# # reverse()
# This method reverses the order of the list.

# %%
colors = ["voilet", "indigo", "blue", "green"]
colors.reverse()
print(colors)
num = [4,2,5,3,6,1,2,1,2,8,9,7]
num.reverse()
print(num)
# Out:
# ['green', 'blue', 'indigo', 'voilet']
# [7, 9, 8, 2, 1, 2, 1, 6, 3, 5, 2, 4]

# %% [markdown]
# ## index()

# %% [markdown]
# This method returns the index of the first occurrence of the list item.

# %%
colors = ["voilet", "green", "indigo", "blue", "green"]
print(colors.index("green"))
num = [4,2,5,6,1,2,1,3,2,8,9,7]
print(num.index(3))
# Out:
# 1
# 7

# %% [markdown]
# ## Before Copy Method

# %%
b = [1,2,3,4,5]
c = b
b[0] = 45
print(b)
print(c)
# Out:
# [45, 2, 3, 4, 5]
# [45, 2, 3, 4, 5]

# %% [markdown]
# ## copy()
# Returns copy of the list. This can be done to perform operations on the list without modifying the original list.

# %%
colors = ["voilet", "green", "indigo", "blue"]
newlist = colors.copy()
print(colors)
print(newlist)
colors[0] = "Yellow"
print(colors)
print(newlist)
# Out:
# ['voilet', 'green', 'indigo', 'blue']
# ['voilet', 'green', 'indigo', 'blue']
# ['Yellow', 'green', 'indigo', 'blue']
# ['voilet', 'green', 'indigo', 'blue']

# %% [markdown]
# ##  append()

# %%
colors = ["voilet", "indigo", "blue"]
colors.append("green")
print(colors)
# Out:
# ['voilet', 'indigo', 'blue', 'green']

# %% [markdown]
# ## insert():
# This method inserts an item at the given index. User has to specify index and the item to be inserted within the insert() method.

# %%
colors = ["voilet", "indigo", "blue"]
#           [0]        [1]      [2]

colors.insert(1, "green")   #inserts item at index 1
# updated list: colors = ["voilet", "green", "indigo", "blue"]
#       indexs              [0]       [1]       [2]      [3]

print(colors)
# Out:
# ['voilet', 'green', 'indigo', 'blue']

# %% [markdown]
# ## extend():
# This method adds an entire list or any other collection datatype (set, tuple, dictionary) to the existing list.

# %%
#add a list to a list
colors = ["voilet", "indigo", "blue"]
rainbow = ["green", "yellow", "orange", "red"]
colors.extend(rainbow)
print(colors)
# Out:
# ['voilet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red']

# %%
number_of_calls = int(input("Enter number of calls: "))
bill_amount = 0
if number_of_calls == 100:
  bill_amount = 200
elif number_of_calls <= 150:
  bill_amount = 200 + (number_of_calls - 100) * 0.60
elif number_of_calls <= 200:
  bill_amount = 200 + (50 * 0.60) + (number_of_calls - 150) * 0.50
else:
  bill_amount = 200 + (50 * 0.60) + (50 * 0.50) + (number_of_calls - 200) * 0.40
print("Your monthly telephone bill is:", bill_amount)
# Out:
# Enter number of calls: 175
# Your monthly telephone bill is: 242.5

# %%
from re import A
# quadratic equation formula b^2+-(sqrt(4ac))/2*a
# for equal roots we have to check condition b^2-4ac = 0
a = int(input("Enter coeffiecient of a "))
b = int(input("enter coeffiecient of b"))
c = int(input("Enter coeffiecient of c" ))
des =b^2-4*a*c
if des== 0:
  print("Equation have two equal roots",b^2/2*a)
elif des> 0:
  root_1= (b^2+(sqrt(4*a*c)))/2*a
  root_2 = (b^2-(sqrt(4*a*c)))/2*a
  print("Equation have real roots",root_1,root_2)
elif des<0:
    print("Equation have imaginary roots")
# Out:
# Enter coeffiecient of a 4
# enter coeffiecient of b5
# Enter coeffiecient of c7
# Equation have imaginary roots
